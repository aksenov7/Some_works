# %%
import re

# %%
corpus = open('germ_content1.txt/part-00000', 'r', encoding='utf-8')

# %%
clean_corpus = open('deutch_cont.txt', 'a', encoding='utf-8')

# %%
for line in corpus:
    line = re.sub('[0-9]', ' ', line)
    line = re.sub(r's+', ' ', line)
    clean_corpus.write(line + '\n')

# %%
corpus = open('deutch_cont.txt', 'r', encoding='utf-8')

# %%
f = 0
for line in corpus:
    f+=1
    if f < 20:
        print(line)
    else:
        break
# Out:
# abi       gh new jahrgang bild forum poll ga tebuch kontaktmarkt info mitglied  gh abi portal logi pa wort regi trier benutz angemeld count up  deut ch abi loading math abi loading engli ch abi loading franz abi loading gk abi loading abiau fahrt loading felix termi loading notenabgab loading mundlich loading abiball loading   min h tag woch monat  eh nr           -      -   uber icht    jahr ehemaligentreff      abi verewigung dahi bild pa wortge chutz er t nachtreff angekundig er  hochzeit  teh abi buch runterlad verge t freu nich abi buch druck jahrgang eit info full neu eintrag er tell   .              joachim breit    jahr bald zeh jahr her abitur mach ganz traditionell jubilaum treff geb  am tag    mai      vorau ichtlich marco polo nauer bab i erfahr eigentlich ja all  chon hor   .              joachim breit ehemaligentreff      freu  gh lad ehemaligentreff   .             uhr nauer  teh hoffentlich bald web eit verei http freu  gh de   .              joachim breit abi verewig
# ...
